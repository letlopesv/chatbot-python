# %%
# !pip install -q chainlit pyngrok langchain optimum
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import chainlit
import langchain
import pyngrok
import optimum

print("Ambiente configurado com sucesso 🚀")
# Out:
# Ambiente configurado com sucesso 🚀

# %% [markdown]
# #Dia 1 – Configuração do Ambiente
# Foram instaladas e importadas as bibliotecas necessárias para o andamento do proejto.

# %%
# !pip install auto-gptq \
  --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu118/ -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.1/126.1 kB 2.4 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# ## AutoGPTQ – Observação
#
# Durante a tentativa de instalação do pacote `auto-gptq`, ocorreu um erro na etapa de geração de metadata.
# Esse comportamento é esperado em ambientes sem suporte completo a CUDA/GPU, uma vez que o AutoGPTQ depende de compilação nativa e recursos específicos de hardware.
#
# O erro não compromete a configuração do ambiente nem a instalação das demais bibliotecas necessárias para a aplicação.

# %% [markdown]
# #Dia 2 – Configuração do Ngrok
#
# Foi realizado a configuração do Ngrok para permitir a exposição de aplicações locais por meio de um túnel público.

# %%
# !pip install pyngrok -q

# %%
from pyngrok import ngrok

ngrok.set_auth_token("SEU_TOKEN_AQUI")
# token removido antes de publicar

# %%
public_url = ngrok.connect(8080)
print("Ngrok URL:", public_url)
# Out:
# Ngrok URL: NgrokTunnel: "https://unbalking-jarred-arumlike.ngrok-free.dev" -> "http://localhost:8080"

# %% [markdown]
# ##Observações
#
# O Ngrok foi configurado com sucesso utilizando o pacote `pyngrok`.
# O túnel público gerado permite o acesso externo a serviços locais, recurso essencial para testes e demonstrações de aplicações web e chatbots.
